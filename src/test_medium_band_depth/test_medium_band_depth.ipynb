# %% [markdown]
# # Test the depth needed for a medium-band catalog to improve photo-z estimation

# %% [markdown]
# # Imports

# %%
import numpy as np
from rail.core.stage import RailPipeline, RailStage
from
